# %% [markdown]
# This is the assignment of deep learning course at Udemy. The code of Keras simplifies the design and realization of deep neural networks compared to tensorflow.

# %%
# Convolutional Neural Network

# Part 1 - Building the CNN

# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import Activation
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense, Dropout
from keras import regularizers
from keras.layers import BatchNormalization
# Out:
# Using TensorFlow backend.

# %% [markdown]
# We can build a 3-layer convolutional neural networks with regularizations to prevent against overfitting. In order to improve performance, we can add batch normalization.

# %%
# Initialising the CNN
classifier = Sequential()

# Step 1 - Convolution
classifier.add(Conv2D(32, (3, 3), input_shape = (64, 64, 3), 
               kernel_regularizer=regularizers.l2(0.001)))
classifier.add(BatchNormalization())
classifier.add(Activation('relu'))

# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Adding a second convolutional layer
classifier.add(Conv2D(32, (3, 3), 
               kernel_regularizer=regularizers.l2(0.001)))
classifier.add(BatchNormalization())
classifier.add(Activation('relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Adding a third convolutional layer
classifier.add(Conv2D(32, (3, 3), 
               kernel_regularizer=regularizers.l2(0.001)))
classifier.add(BatchNormalization())
classifier.add(Activation('relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Adding a fourth convolutional layer
classifier.add(Conv2D(32, (3, 3), 
               kernel_regularizer=regularizers.l2(0.001)))
classifier.add(BatchNormalization())
classifier.add(Activation('relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Step 3 - Flattening
classifier.add(Flatten())
classifier.add(Dropout(0.5))
# Step 4 - Full connection
classifier.add(Dense(units = 128, activation = 'relu', kernel_regularizer=regularizers.l2(0.001)))

classifier.add(Dense(units = 1, activation = 'sigmoid'))

# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# We can use ImageDataGenerator to create more training samples by rescaling, zonming, flipping and etc.

# %%
# Part 2 - Fitting the CNN to the images

from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')

test_set = test_datagen.flow_from_directory('dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %%
keras.initializers.RandomUniform(minval=-0.02, maxval=0.02, seed=111)

# %%
classifier.fit_generator(training_set,
                         steps_per_epoch = 800,
                         epochs = 10,
                         validation_data = test_set,
                         validation_steps = 2000)
# Out:
# Epoch 1/10
# 800/800 [==============================] - 248s - loss: 0.7240 - acc: 0.7136 - val_loss: 0.6170 - val_acc: 0.7778
# Epoch 2/10
# 800/800 [==============================] - 246s - loss: 0.5593 - acc: 0.7953 - val_loss: 0.6629 - val_acc: 0.7234
# Epoch 3/10
# 800/800 [==============================] - 249s - loss: 0.4876 - acc: 0.8259 - val_loss: 0.4544 - val_acc: 0.8444
# Epoch 4/10
# 800/800 [==============================] - 253s - loss: 0.4474 - acc: 0.8414 - val_loss: 0.4710 - val_acc: 0.8282
# Epoch 5/10
# 800/800 [==============================] - 251s - loss: 0.4203 - acc: 0.8519 - val_loss: 0.4096 - val_acc: 0.8645
# Epoch 6/10
# 800/800 [==============================] - 249s - loss: 0.3948 - acc: 0.8660 - val_loss: 0.9250 - val_acc: 0.6440
# Epoch 7/10
# 800/800 [==============================] - 246s - loss: 0.3844 - acc: 0.8686 - val_loss: 0.4078 - val_acc: 0.8580
# Epoch 8/10
# ...

# %%
classifier.fit_generator(training_set,
                         steps_per_epoch = 800,
                         epochs = 10,
                         validation_data = test_set,
                         validation_steps = 2000)
# Out:
# Epoch 1/10
# 800/800 [==============================] - 263s - loss: 0.8162 - acc: 0.6535 - val_loss: 0.9247 - val_acc: 0.5333
# Epoch 2/10
# 800/800 [==============================] - 251s - loss: 0.6480 - acc: 0.7477 - val_loss: 0.6754 - val_acc: 0.6954
# Epoch 3/10
# 800/800 [==============================] - 252s - loss: 0.5564 - acc: 0.7865 - val_loss: 1.0539 - val_acc: 0.5342
# Epoch 4/10
# 800/800 [==============================] - 250s - loss: 0.4979 - acc: 0.8120 - val_loss: 0.5294 - val_acc: 0.7921
# Epoch 5/10
# 800/800 [==============================] - 243s - loss: 0.4644 - acc: 0.8272 - val_loss: 0.4360 - val_acc: 0.8526
# Epoch 6/10
# 800/800 [==============================] - 244s - loss: 0.4382 - acc: 0.8405 - val_loss: 0.5554 - val_acc: 0.7820
# Epoch 7/10
# 800/800 [==============================] - 245s - loss: 0.4287 - acc: 0.8474 - val_loss: 0.4036 - val_acc: 0.8744
# Epoch 8/10
# ...
